# %%
import os
from dotenv import load_dotenv
from pathlib import Path
from google.oauth2 import service_account
from google.cloud import storage, bigquery

load_dotenv()

ROOT = Path.cwd().parent

# Id du projet
PROJECT_ID  = os.getenv("PROJECT_ID")
# Configuration du service account
SA_PATH = ROOT / os.getenv("GOOGLE_APPLICATION_CREDENTIALS")
# Configuration du bucket GCS
BUCKET_NAME = os.getenv("BUCKET_NAME")

# %%
# 1) Charger les credentials du fichier JSON
creds = service_account.Credentials.from_service_account_file(SA_PATH)
st = storage.Client(project=PROJECT_ID, credentials=creds)

print(f"Auth OK — storage : {st.project}")
print(f"Liste des buckets : {list(st.list_buckets())}")

# Lister les fichiers dans le bucket
bucket = st.bucket(BUCKET_NAME)
print(f"Fichiers dans le bucket '{BUCKET_NAME}':")
print("-" * 50)

blobs = bucket.list_blobs()
file_count = 0

for blob in blobs:
    print(f"[FILE] {blob.name}")
    print(f"   Taille: {blob.size} bytes")
    print(f"   Créé: {blob.time_created}")
    print(f"   Modifié: {blob.updated}")
    print("-" * 50)
    file_count += 1

print(f"\nTotal: {file_count} fichiers trouvés")
# Out:
# Auth OK — storage : univ-reims-sncf-forecast
# Liste des buckets : [<Bucket: bronze-sncf-etl>]
# Fichiers dans le bucket 'bronze-sncf-etl':
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2015/data-rf-2015/2015S1_NB_FER.csv
#    Taille: 43630580 bytes
#    Créé: 2025-10-23 18:54:47.336000+00:00
#    Modifié: 2025-10-23 18:54:47.336000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2015/data-rf-2015/2015S1_PROFIL_FER.csv
#    Taille: 3876455 bytes
#    Créé: 2025-10-23 18:54:48.491000+00:00
#    Modifié: 2025-10-23 18:54:48.491000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2015/data-rf-2015/2015S2_NB_FER.csv
#    Taille: 44905124 bytes
#    Créé: 2025-10-23 18:54:51.204000+00:00
#    Modifié: 2025-10-23 18:54:51.204000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2015/data-rf-2015/2015S2_PROFIL_FER.csv
#    Taille: 4251666 bytes
#    Créé: 2025-10-23 18:54:52.378000+00:00
#    Modifié: 2025-10-23 18:54:52.378000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2016/data-rf-2016/2016S1_NB_FER.txt
#    Taille: 50851781 bytes
#    Créé: 2025-10-23 18:54:55.194000+00:00
#    Modifié: 2025-10-23 18:54:55.194000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2016/data-rf-2016/2016S1_PROFIL_FER.txt
#    Taille: 4263858 bytes
#    Créé: 2025-10-23 18:54:56.366000+00:00
#    Modifié: 2025-10-23 18:54:56.366000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2016/data-rf-2016/2016S2_NB_FER.txt
#    Taille: 50500260 bytes
#    Créé: 2025-10-23 18:54:59.355000+00:00
#    Modifié: 2025-10-23 18:54:59.355000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2016/data-rf-2016/2016S2_PROFIL_FER.txt
#    Taille: 4284411 bytes
#    Créé: 2025-10-23 18:55:00.642000+00:00
#    Modifié: 2025-10-23 18:55:00.642000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2017/data-rf-2017/2017S1_NB_FER.txt
#    Taille: 50913654 bytes
#    Créé: 2025-10-23 18:55:03.386000+00:00
#    Modifié: 2025-10-23 18:55:03.386000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2017/data-rf-2017/2017S1_PROFIL_FER.txt
#    Taille: 4290379 bytes
#    Créé: 2025-10-23 18:55:04.571000+00:00
#    Modifié: 2025-10-23 18:55:04.571000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2017/data-rf-2017/2017_S2_NB_FER.txt
#    Taille: 45977574 bytes
#    Créé: 2025-10-23 18:55:08.437000+00:00
#    Modifié: 2025-10-23 18:55:08.437000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2017/data-rf-2017/2017_S2_PROFIL_FER.txt
#    Taille: 4300416 bytes
#    Créé: 2025-10-23 18:55:09.623000+00:00
#    Modifié: 2025-10-23 18:55:09.623000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2018/data-rf-2018/2018_S1_NB_FER.txt
#    Taille: 48559258 bytes
#    Créé: 2025-10-23 18:55:12.435000+00:00
#    Modifié: 2025-10-23 18:55:12.435000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2018/data-rf-2018/2018_S1_PROFIL_FER.txt
#    Taille: 4265432 bytes
#    Créé: 2025-10-23 18:55:13.657000+00:00
#    Modifié: 2025-10-23 18:55:13.657000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2018/data-rf-2018/2018_S2_NB_Fer.txt
#    Taille: 50693075 bytes
#    Créé: 2025-10-23 18:55:16.392000+00:00
#    Modifié: 2025-10-23 18:55:16.392000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2018/data-rf-2018/2018_S2_Profil_Fer.txt
#    Taille: 4301334 bytes
#    Créé: 2025-10-23 18:55:17.579000+00:00
#    Modifié: 2025-10-23 18:55:17.579000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2019/data-rf-2019/2019_S1_NB_FER.txt
#    Taille: 52560640 bytes
#    Créé: 2025-10-23 18:55:20.443000+00:00
#    Modifié: 2025-10-23 18:55:20.443000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2019/data-rf-2019/2019_S1_PROFIL_FER.txt
#    Taille: 4321931 bytes
#    Créé: 2025-10-23 18:55:21.639000+00:00
#    Modifié: 2025-10-23 18:55:21.639000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2019/data-rf-2019/2019_S2_NB_FER.txt
#    Taille: 53932375 bytes
#    Créé: 2025-10-23 18:55:24.545000+00:00
#    Modifié: 2025-10-23 18:55:24.545000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2019/data-rf-2019/2019_S2_PROFIL_FER.txt
#    Taille: 4298077 bytes
#    Créé: 2025-10-23 18:55:25.787000+00:00
#    Modifié: 2025-10-23 18:55:25.787000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2020/data-rf-2020/2020_S1_NB_FER.txt
#    Taille: 50122740 bytes
#    Créé: 2025-10-23 18:55:28.286000+00:00
#    Modifié: 2025-10-23 18:55:28.286000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2020/data-rf-2020/2020_S1_PROFIL_FER.txt
#    Taille: 4159364 bytes
#    Créé: 2025-10-23 18:55:29.447000+00:00
#    Modifié: 2025-10-23 18:55:29.447000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2020/data-rf-2020/2020_S2_NB_FER.txt
#    Taille: 59655297 bytes
#    Créé: 2025-10-23 18:55:32.082000+00:00
#    Modifié: 2025-10-23 18:55:32.082000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2020/data-rf-2020/2020_S2_PROFIL_FER.txt
#    Taille: 4264510 bytes
#    Créé: 2025-10-23 18:55:33.356000+00:00
#    Modifié: 2025-10-23 18:55:33.356000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2021/data-rf-2021/2021_S1_NB_FER.txt
#    Taille: 60329902 bytes
#    Créé: 2025-10-23 18:55:36.344000+00:00
#    Modifié: 2025-10-23 18:55:36.344000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2021/data-rf-2021/2021_S1_PROFIL_FER.txt
#    Taille: 4205652 bytes
#    Créé: 2025-10-23 18:55:37.516000+00:00
#    Modifié: 2025-10-23 18:55:37.516000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2021/data-rf-2021/2021_S2_NB_FER.txt
#    Taille: 61617131 bytes
#    Créé: 2025-10-23 18:55:40.488000+00:00
#    Modifié: 2025-10-23 18:55:40.488000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2021/data-rf-2021/2021_S2_PROFIL_FER.txt
#    Taille: 4327951 bytes
#    Créé: 2025-10-23 18:55:41.730000+00:00
#    Modifié: 2025-10-23 18:55:41.730000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2022/data-rf-2022/2022_S1_NB_FER.txt
#    Taille: 61898940 bytes
#    Créé: 2025-10-23 18:55:44.436000+00:00
#    Modifié: 2025-10-23 18:55:44.436000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2022/data-rf-2022/2022_S1_PROFIL_FER.txt
#    Taille: 4332613 bytes
#    Créé: 2025-10-23 18:55:45.618000+00:00
#    Modifié: 2025-10-23 18:55:45.618000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2022/data-rf-2022/2022_S2_NB_FER.txt
#    Taille: 60958124 bytes
#    Créé: 2025-10-23 18:55:48.429000+00:00
#    Modifié: 2025-10-23 18:55:48.429000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2022/data-rf-2022/2022_S2_PROFIL_FER.txt
#    Taille: 4289652 bytes
#    Créé: 2025-10-23 18:55:49.599000+00:00
#    Modifié: 2025-10-23 18:55:49.599000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2023/data-rf-2023/2023_S1_NB_FER .txt
#    Taille: 60479702 bytes
#    Créé: 2025-10-23 18:55:52.365000+00:00
#    Modifié: 2025-10-23 18:55:52.365000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2023/data-rf-2023/2023_S1_PROFIL_FER.txt
#    Taille: 4236448 bytes
#    Créé: 2025-10-23 18:55:53.537000+00:00
#    Modifié: 2025-10-23 18:55:53.537000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2023/data-rf-2023/2023_S2_NB_FER.txt
#    Taille: 103908006 bytes
#    Créé: 2025-10-23 18:55:57.661000+00:00
#    Modifié: 2025-10-23 18:55:57.661000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2023/data-rf-2023/2023_S2_PROFIL_FER.txt
#    Taille: 4180379 bytes
#    Créé: 2025-10-23 18:55:58.834000+00:00
#    Modifié: 2025-10-23 18:55:58.834000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2024/2024_S1_NB_FER.txt
#    Taille: 52643974 bytes
#    Créé: 2025-10-23 18:56:01.335000+00:00
#    Modifié: 2025-10-23 18:56:01.335000+00:00
# --------------------------------------------------
# [FILE] bronze/histo-validations-reseau-ferre/2024/2024_S1_PROFIL_FER.txt
#    Taille: 4239100 bytes
#    Créé: 2025-10-23 18:56:02.549000+00:00
#    Modifié: 2025-10-23 18:56:02.549000+00:00
# --------------------------------------------------
# [FILE] titanic.csv
#    Taille: 39720 bytes
#    Créé: 2025-10-18 13:48:15.278000+00:00
#    Modifié: 2025-10-18 13:48:15.278000+00:00
# --------------------------------------------------
#
# Total: 39 fichiers trouvés
